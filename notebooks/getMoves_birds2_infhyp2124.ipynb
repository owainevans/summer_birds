# %%
cd ~/birds
# Out:
# /home/owainevans/birds

# %%
# %run plotMoves.py
# Out:
# Using 2 particles
# /usr/lib/pymodules/python2.7/matplotlib/__init__.py:923: UserWarning:  This call to matplotlib.use() has no effect
# because the the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   if warn: warnings.warn(_use_error_msg)

# %% [markdown]
# Plot:
# xaxis is the cell number. we plot the number of birds leaving each cell

# %%
# RUN INFORMATION
# birds2, year 1, running all 19 days
# 1000 transitions and 1 iteration (so 1 posterior sample per day)
noIters=6
path = 'prior20_7day_noslice_getMoves_2124/'
allMoves,allMovesGround,fig = plotMoves(path)
# Out:
# allMoves total for day 0 (up to 6): 1018
# allMoves total for day 1 (up to 6): 1011
# allMoves total for day 2 (up to 6): 1012
# allMoves total for day 3 (up to 6): 1013
# allMoves total for day 4 (up to 6): 1009
# allMoves total for day 0 (up to 6): 1000
# allMoves total for day 1 (up to 6): 1000
# allMoves total for day 2 (up to 6): 1000
# allMoves total for day 3 (up to 6): 1000
# allMoves total for day 4 (up to 6): 1000
# allMoves total for day 5 (up to 6): 1000

# %%
logs=[[(1, 0, 200, -16180.570202595405, 1355329.0, (-24.143916918229117, 11.09776318156496, -9.506187037544462, -14.785904279286534), 3.752295970916748), (1, 1, 200, -30.216387398306093, 49.0, (-21.11281843802751, -10.74522626835958, 10.51861019318079, 4.419208286175283), 7.634018898010254), (1, 2, 200, -31.10680958797263, 256.0, (-8.977453039083374, -8.869076110210928, -19.97470527895277, 26.282944236771506), 7.6582770347595215), (1, 3, 200, -30.42143515190274, 1.0, (6.200673309368557, -0.9417749277715779, -12.92436125986151, 26.282944236771506), 7.487622976303101), (1, 4, 200, -32.96850706436769, 900.0, (6.424715138369041, -27.830967666045748, 37.201852220866456, 6.1497349096312925), 7.528354167938232), (1, 5, 200, -31.89748774912343, 49.0, (-6.864143778805741, 0.7759436958512018, 43.43274943870328, 10.106399901832914), 7.720837831497192), (1, 6, 200, -31.784275690206485, 676.0, (-6.864143778805741, 0.7759436958512018, 33.59690600355491, 15.902114161901006), 8.230508089065552), (2, 0, 200, -6140.232900582267, 368062.0, (-6.864143778805741, 0.7759436958512018, 33.59690600355491, 15.902114161901006), 9.363770008087158), (2, 1, 200, -2550.0262434481383, 342605.0, (-6.864143778805741, 12.155314364686996, 27.018953481029364, 15.902114161901006), 40.92048907279968), (2, 2, 200, -2467.083332732842, 322190.0, (-6.864143778805741, 12.155314364686996, 27.018953481029364, 15.902114161901006), 55.87118196487427), (2, 3, 200, -2460.5760780187225, 320880.0, (-6.864143778805741, 12.155314364686996, 27.018953481029364, 15.902114161901006), 51.200748920440674), (2, 4, 200, -1169.1994445755295, 210225.0, (8.115295618999328, 12.155314364686996, 27.018953481029364, 15.902114161901006), 45.37497115135193), (2, 5, 200, -1143.4071443131616, 210284.0, (8.115295618999328, 12.155314364686996, 27.018953481029364, 15.902114161901006), 44.02217388153076), (2, 6, 200, -826.3626900491869, 270029.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 51.9474310874939), (3, 0, 200, -1640.1933399700786, 282328.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 14.204591989517212), (3, 1, 200, -1612.8082300343904, 281823.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 114.16154885292053), (3, 2, 200, -1538.8208713816623, 270995.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 123.5517110824585), (3, 3, 200, -1527.5107654166907, 270750.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 105.01725506782532), (3, 4, 200, -1508.4508494546083, 269496.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 108.56111097335815), (3, 5, 200, -1510.7766057282754, 269547.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 101.19940900802612), (3, 6, 200, -1508.3166272263838, 269135.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 111.65699601173401), (4, 0, 200, -2200.2096449949618, 265089.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 14.909687042236328), (4, 1, 200, -2163.0174725379466, 261082.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 91.85046195983887), (4, 2, 200, -2150.3970540460477, 249294.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 129.98345589637756), (4, 3, 200, -2131.7901460075764, 247191.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 158.2676260471344), (4, 4, 200, -2131.7901460075764, 247191.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 101.19270992279053), (4, 5, 200, -2131.7901460075764, 247191.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 128.55052399635315), (4, 6, 200, -2108.8707237863005, 226660.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 133.15610599517822), (5, 0, 200, -2760.5784579773012, 240001.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 15.955811023712158), (5, 1, 200, -2737.3738968499083, 237573.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 71.94422793388367), (5, 2, 200, -2736.1971137562577, 237413.0, (8.115295618999328, 12.004335750505701, 14.549145152134232, 15.902114161901006), 74.48448300361633), (5, 3, 200, -2590.124113198692, 87044.0, (8.115295618999328, 12.004335750505701, 16.811483377517337, 15.902114161901006), 55.25267720222473), (5, 4, 200, -2557.7744841209974, 82527.0, (8.115295618999328, 12.004335750505701, 16.811483377517337, 15.902114161901006), 64.92320895195007), (5, 5, 200, -2557.3043045234167, 81620.0, (8.115295618999328, 12.004335750505701, 16.811483377517337, 15.902114161901006), 65.08334183692932), (5, 6, 200, -2542.301768243199, 77921.0, (8.115295618999328, 12.004335750505701, 16.811483377517337, 15.902114161901006), 64.92581820487976)]]
if len(logs)==1:
    logs = logs[0]
print 'first line of each day is prior (no inference)'
print 'logscore, sqrt(L2score), time (s)\n'

for i,data in enumerate(logs):
    if np.mod(i,noIters+1)==0:
        print '\nDay %i ----'%(i/(noIters+1.))
    triple = data[3],data[4],data[-1]
    sqrt_triple = triple[0],triple[1],triple[1]**.5,triple[2]
    print map(lambda x:round(x,2),sqrt_triple), 'params: ',np.round(data[5],2)
    
    
    
## inferences for normal 0 30, with 20 iterations of 10 transitions of mh one days 1 and 2 (4 parallel runs)

[2, 11, 200, -848.80999999999995, 62624.0, array([  1.07,   4.23,  19.11,  11.12]), 51.93]
Inf_prog = (cycle ((mh hypers one 10) (mh 1 one 200)) 1)
[2, 9, 200, -8490.1000000000004, 250272.0, array([  4.71, -55.12,  17.12, -10.29]), 61.560000000000002]
Inf_prog = (cycle ((mh hypers one 10) (mh 1 one 200)) 1)
[2, 5, 200, -11833.280000000001, 326427.0, array([-32.  ,   8.48,   5.24,  -1.52]), 135.99000000000001]
Inf_prog = (cycle ((mh hypers one 10) (mh 1 one 200)) 1)
[2, 8, 200, -3242.1399999999999, 240780.0, array([ 38.65,   9.95,   3.63,  21.86]), 89.480000000000004]
Inf_prog = (cycle ((mh hypers one 10) (mh 1 one 200)) 1)
[2, 12, 200, -842.53999999999996, 62463.0, array([  1.07,   4.23,  19.11,  11.12]), 47.039999999999999]
Inf_prog = (cycle ((mh hypers one 10) (mh 1 one 200)) 1)
[2, 10, 200, -8487.8999999999996, 248009.0, array([  4.71, -55.12,  17.12, -10.29]), 54.759999999999998]
# Out:
#  first line of each day is prior (no inference)
# logscore, sqrt(L2score), time (s)
#
#
# Day 0 ----
# [-16180.57, 1355329.0, 1164.19, 3.75] params:  [-24.14  11.1   -9.51 -14.79]
# [-30.22, 49.0, 7.0, 7.63] params:  [-21.11 -10.75  10.52   4.42]
# [-31.11, 256.0, 16.0, 7.66] params:  [ -8.98  -8.87 -19.97  26.28]
# [-30.42, 1.0, 1.0, 7.49] params:  [  6.2   -0.94 -12.92  26.28]
# [-32.97, 900.0, 30.0, 7.53] params:  [  6.42 -27.83  37.2    6.15]
# [-31.9, 49.0, 7.0, 7.72] params:  [ -6.86   0.78  43.43  10.11]
# [-31.78, 676.0, 26.0, 8.23] params:  [ -6.86   0.78  33.6   15.9 ]
#
# Day 1 ----
# [-6140.23, 368062.0, 606.68, 9.36] params:  [ -6.86   0.78  33.6   15.9 ]
# [-2550.03, 342605.0, 585.32, 40.92] params:  [ -6.86  12.16  27.02  15.9 ]
# [-2467.08, 322190.0, 567.62, 55.87] params:  [ -6.86  12.16  27.02  15.9 ]
# [-2460.58, 320880.0, 566.46, 51.2] params:  [ -6.86  12.16  27.02  15.9 ]
# [-1169.2, 210225.0, 458.5, 45.37] params:  [  8.12  12.16  27.02  15.9 ]
# ...

# %%
import numpy as np
np.round( [1.1111,[2.222222,[3.33333]]] )

# %%
no_days=19
#fig,ax = plt.subplots(no_days,1,figsize=(10,3*no_days) )
#[ax[i].plot(allMovesGround[i]) for i in range(no_days)];

# %%
plotSamples(path,noIters=noIters)

# Comparing L2 posterior and prior L2 and logscores (collapsing over all 19 days)
# here we only do 1000 transitions and so get one sample for posterior for each day
